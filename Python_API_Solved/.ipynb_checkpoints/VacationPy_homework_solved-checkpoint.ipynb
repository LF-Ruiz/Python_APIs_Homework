# %% [markdown]
# # VacationPy
# ----
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.

# %%
# !pip install gmaps
# Out:
# Requirement already satisfied: gmaps in c:\users\luisf\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\luisf\anaconda3\lib\site-packages (from gmaps) (7.5.1)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\luisf\anaconda3\lib\site-packages (from gmaps) (7.16.1)
# Requirement already satisfied: six in c:\users\luisf\anaconda3\lib\site-packages (from gmaps) (1.15.0)
# Requirement already satisfied: geojson>=2.0.0 in c:\users\luisf\anaconda3\lib\site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\luisf\anaconda3\lib\site-packages (from gmaps) (4.3.3)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\luisf\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.0.7)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\luisf\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\luisf\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.2)
# Requirement already satisfied: pickleshare in c:\users\luisf\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\luisf\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.3)
# Requirement already satisfied: backcall in c:\users\luisf\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in c:\users\luisf\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.17.1)
# Requirement already satisfied: decorator in c:\users\luisf\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (4.4.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\luisf\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.5)
# Requirement already satisfied: pygments in c:\users\luisf\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (2.6.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\luisf\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (49.2.0.post20200714)
# Requirement already satisfied: ipython-genutils in c:\users\luisf\anaconda3\lib\site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: jupyter-core in c:\users\luisf\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.6.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\luisf\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\luisf\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.3)
# Requirement already satisfied: jupyter-client in c:\users\luisf\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.6)
# Requirement already satisfied: tornado>=4.2 in c:\users\luisf\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.4)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\luisf\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\luisf\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\luisf\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (227)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\luisf\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (19.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\luisf\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.16.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\luisf\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (19.0.1)
# Requirement already satisfied: nbconvert in c:\users\luisf\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (5.6.1)
# Requirement already satisfied: Send2Trash in c:\users\luisf\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: prometheus-client in c:\users\luisf\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.0)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\luisf\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.3)
# Requirement already satisfied: jinja2 in c:\users\luisf\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\luisf\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\luisf\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: defusedxml in c:\users\luisf\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: testpath in c:\users\luisf\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\luisf\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\luisf\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: bleach in c:\users\luisf\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.1.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\luisf\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: packaging in c:\users\luisf\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.4)
# Requirement already satisfied: webencodings in c:\users\luisf\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\luisf\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.4.7)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_api
g_api
# Out:
# 'AIzaSyCmgWYXTbK3SDy1PwEgPK_cxxKd6mOYlcM'

# %% [markdown]
# ## Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
#load csv into dataframe
cities_csv = "cities_results.csv"
city_df = pd.read_csv(cities_csv)
city_df.head()
# Out:
#    Index     City Country                 Date    Lat     Lng  Max Temp (F)  \
# 0      0  Talnakh      RU  2020-12-15 18:05:15  69.49   88.40        -11.20
# 1      1  Qaanaaq      GL  2020-12-15 18:05:15  77.48  -69.36         -1.70
# 2      2  Klyuchi      RU  2020-12-15 18:05:15  52.27   79.17          4.53
# 3      3     Chui      UY  2020-12-15 18:05:15 -33.70  -53.46         78.03
# 4      4   Kerema      PG  2020-12-15 18:05:15  -7.96  145.78         77.56
#
#    Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# 0            76              75             13.42
# 1            64               0              8.52
# 2            94              95              8.08
# 3            42               0             13.04
# 4            82             100              3.80

# %% [markdown]
# Humidity Heatmap
# Configure gmaps.
# Use the Lat and Lng as locations and Humidity as the weight.
# Add Heatmap layer to map.

# %%
# Configure gmaps
gmaps.configure(api_key=g_api)

# %%
# Store latitude and longitude in locations
locations = city_df[["Lat", "Lng"]]

# %%
# Create heat map of all cities based on humidity.

# Humidity values as floats
Humidity = city_df["Humidity (%)"].astype(float)

# Map zoom and centering
coordinates = (38, 1.51)   # Centered on Caravaca de la Cruz, Spain
fig1 = gmaps.figure(center=coordinates, zoom_level=1.5)     # Zoomed to look better initially

# Create heat layer
heat_layer1 = gmaps.heatmap_layer(locations, weights=Humidity,dissipating=False, max_intensity=100,point_radius=1)

# Add layer
fig1.add_layer(heat_layer1)

# Display figure
fig1
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Save gmap image as .png file
#fig1.savefig('Vacation1.png')
#fig1.write_image(file='Vacation1.png', format='.png')
plt.savefig('Vacation1.png', dpi=None, facecolor='w', edgecolor='w',
        orientation='portrait', papertype=None, format=None,
        transparent=False, bbox_inches=None, pad_inches=0.1,
        frameon=None, metadata=None)
# Out:
# <ipython-input-7-5be4bc15e240>:4: MatplotlibDeprecationWarning:
# The frameon kwarg was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use facecolor instead.
#   plt.savefig('Vacation1.png', dpi=None, facecolor='w', edgecolor='w',

# %%
# Choose the appx 10 cities with the most ideal temperature, wind speed, and cloudiness.
vac_city_df = city_df.copy()
vac_city_df = vac_city_df.dropna()
vac_city_df = vac_city_df[vac_city_df['Max Temp (F)'] >= 68]
vac_city_df = vac_city_df[vac_city_df['Max Temp (F)'] <= 77]  
vac_city_df = vac_city_df[vac_city_df['Wind Speed (mph)'] <= 10]
vac_city_df = vac_city_df[vac_city_df['Cloudiness (%)'] == 0]

vac_city_df = vac_city_df.reset_index()
vac_city_df
# Out:
#    index  Index          City Country                 Date    Lat    Lng  \
# 0     78     78     Abu Dhabi      AE  2020-12-15 18:05:29  24.47  54.37
# 1    290    290     Marrakesh      MA  2020-12-15 18:01:42  31.63  -8.01
# 2    299    299        Manama      BH  2020-12-15 18:06:25  26.22  50.58
# 3    342    342         Dakar      SN  2020-12-15 18:06:31  14.69 -17.44
# 4    369    369       Salalah      OM  2020-12-15 18:06:36  17.02  54.09
# 5    518    518  General Roca      AR  2020-12-15 18:06:58 -39.03 -67.58
# 6    533    533    Tlanchinol      MX  2020-12-15 18:07:01  20.98 -98.65
#
#    Max Temp (F)  Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# 0          73.4            64               0              6.93
# 1          68.0            52               0              2.24
# 2          69.8            68               0              2.24
# 3          77.0            69               0              9.17
# 4          75.2            53               0              3.36
# 5          69.8            32               0              9.17
# 6          71.1            58               0              3.06

# %% [markdown]
# Hotel Map
# Store into variable named hotel_df.
# Add a "Hotel Name" column to the DataFrame.
# Set parameters to search for hotels with 5000 meters.
# Hit the Google Places API for each city's coordinates.
# Store the first Hotel result into the DataFrame.
# Plot markers on top of the heatmap.

# %%
# Create hotel_df with empty hotel name column
hotel_df = vac_city_df
hotel_df["Hotel Name"] = np.nan
hotel_df = hotel_df.drop(columns='index')
hotel_df
# Out:
#    Index          City Country                 Date    Lat    Lng  \
# 0     78     Abu Dhabi      AE  2020-12-15 18:05:29  24.47  54.37
# 1    290     Marrakesh      MA  2020-12-15 18:01:42  31.63  -8.01
# 2    299        Manama      BH  2020-12-15 18:06:25  26.22  50.58
# 3    342         Dakar      SN  2020-12-15 18:06:31  14.69 -17.44
# 4    369       Salalah      OM  2020-12-15 18:06:36  17.02  54.09
# 5    518  General Roca      AR  2020-12-15 18:06:58 -39.03 -67.58
# 6    533    Tlanchinol      MX  2020-12-15 18:07:01  20.98 -98.65
#
#    Max Temp (F)  Humidity (%)  Cloudiness (%)  Wind Speed (mph)  Hotel Name
# 0          73.4            64               0              6.93         NaN
# 1          68.0            52               0              2.24         NaN
# 2          69.8            68               0              2.24         NaN
# 3          77.0            69               0              9.17         NaN
# 4          75.2            53               0              3.36         NaN
# 5          69.8            32               0              9.17         NaN
# 6          71.1            58               0              3.06         NaN

# %%
#url = https://maps.googleapis.com/maps/api/place/findplacefromtext/output?parameters
#https://maps.googleapis.com/maps/api/place/nearbysearch/output?parameters

# %%
# Search GooglePlaces for hotels within 5000 meters
# List for hotel names
hotels = []

# Initialize counter
x = 0

# Print header
print("Beginning Data Retrieval")
print("----------------------------")

# Loop to search based on city Lat and Long
for cities in hotel_df['City']:
    
    target_coordinates = str(hotel_df['Lat'][x])+' , '+str(hotel_df['Lng'][x])
    x+=1
    target_radius = 5000    # in meters
    target_type = 'hotel'
    params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": g_api
    }
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    try:
        print(f"Processing Record") 
        response = requests.get(base_url, params=params)
        print(f"response")
        hotel_results = response.json()
        hotels.append(hotel_results['results'][0]['name'])
        
    except IndexError:
        hotels.append(np.nan)
        print(f"City not found. Skipping...")
        
# Print completion
print("----------------------------")
print("Data Retrieval Complete")
print("----------------------------")

# Append dataframe with hotel names
hotel_df['Hotel Name'] = hotels

# Drop cities with no resulting hotel
#hotel_df = hotel_df.dropna()

hotel_df
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record
# response
# City not found. Skipping...
# Processing Record
# response
# City not found. Skipping...
# Processing Record
# response
# City not found. Skipping...
# Processing Record
# response
# City not found. Skipping...
# Processing Record
# response
# City not found. Skipping...
# Processing Record
# response
# City not found. Skipping...
# Processing Record
# response
# City not found. Skipping...
# ----------------------------
# Data Retrieval Complete
# ----------------------------
#    Index          City Country                 Date    Lat    Lng  \
# 0     78     Abu Dhabi      AE  2020-12-15 18:05:29  24.47  54.37
# 1    290     Marrakesh      MA  2020-12-15 18:01:42  31.63  -8.01
# 2    299        Manama      BH  2020-12-15 18:06:25  26.22  50.58
# 3    342         Dakar      SN  2020-12-15 18:06:31  14.69 -17.44
# 4    369       Salalah      OM  2020-12-15 18:06:36  17.02  54.09
# 5    518  General Roca      AR  2020-12-15 18:06:58 -39.03 -67.58
# 6    533    Tlanchinol      MX  2020-12-15 18:07:01  20.98 -98.65
#
#    Max Temp (F)  Humidity (%)  Cloudiness (%)  Wind Speed (mph)  Hotel Name
# 0          73.4            64               0              6.93         NaN
# 1          68.0            52               0              2.24         NaN
# 2          69.8            68               0              2.24         NaN
# 3          77.0            69               0              9.17         NaN
# 4          75.2            53               0              3.36         NaN
# 5          69.8            32               0              9.17         NaN
# 6          71.1            58               0              3.06         NaN

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Plot Ideal Weather Cities Heatmap

# Humidity values as floats
#hotel_df
Humidity1 = city_df["Humidity (%)"].astype(float)

# Map zoom and centering
fig = gmaps.figure(center=coordinates, zoom_level=2.0)   # Zoomed for visually appealing presentation
locations = city_df[['Lat','Lng']]
weights = Humidity1
#fig = gmaps.figure
#fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
#fig

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=Humidity1, dissipating=False, max_intensity=50, point_radius=1)

# Create marker layer
markers = gmaps.marker_layer(locations,)
#    info_box_content=hotel_info)

# Add layers
fig.add_layer(heat_layer)
fig.add_layer(markers)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Save gmap image as .png file
#fig.savefig('Vacation-Map.png')
plt.savefig('Vacation-Map.png', dpi=None, facecolor='w', edgecolor='w',
        orientation='portrait', papertype=None, format=None,
        transparent=False, bbox_inches=None, pad_inches=0.1,
        metadata=None)
